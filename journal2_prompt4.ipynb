# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,100, 1000)
r = np.random.exponential(x)
t = plt.hist(r, bins=100)
plt.xlabel('x')
plt.ylabel('random exponential')

plt.savefig('journal2_prompt4_figure.pdf')
plt.show()
