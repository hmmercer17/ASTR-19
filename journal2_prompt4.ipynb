# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
r = np.random.gumbel(size=1000)

t = plt.hist(r, bins=100)
plt.title('Brussel Sprouts Rating From 0-10, but people ignored the scale b/c they hate brussel sprouts that much')
plt.xlabel('Rating')
plt.ylabel('Number of People')
plt.savefig('journal2_prompt4_figure.pdf')
plt.show()
