# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating a Data Set, REUSE DATA U CREATED IN PROMPT 1 FOR THIS PROMPT

# %%
x = np.linspace(0,2*np.pi,100)

def func(x, a, b):
    return a*np.exp(-b*x)

a = 4
b = 2.7
# Out:
# Text(0, 0.5, 'y_og')

# %%
y = func(x, a, b)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('$y = 4e^{-2.7x}$')

plt.savefig('journal2_prompt1_figure.pdf')
plt.show()

# %% [markdown]
# ### Adding Scatter to Dataset

# %%
sigma = np.linspace(2, 0.2, len(x))

scatter = np.random.normal(loc = 0, scale = sigma)

y_scatter = y + scatter

y_err = np.full(100, sigma)

plt.figure(figsize = (8,5))
plt.errorbar(x, y_scatter, yerr = y_err ,fmt = '*', c = 'g')

plt.xlabel('x')
plt.ylabel('y with scatter')

plt.savefig('journal_prompt2_figure.pdf')
plt.show()
